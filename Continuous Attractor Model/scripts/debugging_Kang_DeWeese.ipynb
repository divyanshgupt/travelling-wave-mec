# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import pickle
from tqdm import tqdm

# %%
recordings_file = 'data/2022-04-04 14:16_40neurons/recordings'
# recordings_file = 'data/2022-04-04 14:16_40neurons/recordings'
recordings = pd.read_pickle(recordings_file)

# %%
velocity_array, state_rec, spike_rec = recordings
velocity_array_x, velocity_array_y = velocity_array
State_n, State_e, State_w, State_s, State_i = state_rec
M_n, M_e, M_w, M_s, M_i = spike_rec

# %%
plt.plot(velocity_array_x, velocity_array_y)
